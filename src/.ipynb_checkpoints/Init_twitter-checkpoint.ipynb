# %% [markdown]
# ## Пролог
#
# Метою цього прикладу є збір твітів з Twitter з використанням API v2 з допомогою Python 3. Це включатиме покроковий процес від налаштування, доступу до кінцевих точок (*End Points*) до збереження твітів, зібраних у форматі CSV.
#
# Перед запуском прикладу був отриманий доступ Порталу Розробника Твіттера, там створений Проєкт *SCENTSCAPE* і в проєкті створений застосунок *scent_scape_app*. Також в процесі були отримані та збережені ключі доступу застосунку, так звані, *Bearer Token* та *Access Token and Secret*. Ці деталі тут не висвітлені. З огляду на вам потрібно самостійно отримати обліковку на Порталі Розробника Твіттер. Це займе певний час через веріфікацію службою Твіттер наданої вами інформації. Можуть, як у моєму випадку, поставити додаткові питання. Тобто від вимагається чіткість формулювань і певна терплячість.
#
# Цей приклад побудований на статті [Collecting tweets from Twitter API v2 using Python 3 | Towards Data Science](https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a). У мене немає обліковки API Розробника Тіттер для Академічних досліджень, що дозволяє безкоштовно видобувати 10 млн. твітерів щомісяця. Тому я модифікував код так, щоб отримувати твітери в межах останніх 7 днів. Також у коді виправлена одна явна помилка.

# %% [markdown]
# ## Основні бібліотеки
#
# Перед початком імпортуємо деякі основні бібліотеки для цього, необхідні для цього прикладу:

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time
import json

# %% [markdown]
# ## Підготовка авторизації
#
# Ми досягли цієї точки і, отже, маємо право надіслати свій перший запит з API. По-перше, ми створимо функцію `auth()`, що матиме *Bearer Token* із застосунку, що ми щойно створили. Оскільки цей токен є конфіденційною інформацією, ми не повинні ділитися ним взагалі з ким-небудь.
#
# Отже, спочатку збережемо токен в окремому JSON-файлі 'config_auth.json':
#
# ```json
#   {
#     "token": "<тут-розміщений-ваш-токен>"
#   }
# ```
#
# Відносний шлях цього файлу включимо до списку `.gitignore`, щоб запобігти його копіюванню на зовнішній ресурс *github*:
#
# ```
#   src/config_auth.json
# ```
#
# Після цього прочитаємо наш токен з JSON-файлу:

# %%
config_json = 'config_auth.json'
with open(config_json) as config_json_file:
    config = json.load(config_json_file)

def auth():
    return config['token']

# control display
auth()

# %% [markdown]
# Далі визначимо функцію, що візьме наш токен, передасть його на авторизацію та поверне заголовки, що ми використовуватимемо для доступу до API.

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# control display
create_headers(auth())

# %% [markdown]
# ## Створюємо URL і параметри запиту для кінцевої точки
#
# Після отримання доступу до API створимо запит на кінцеву точку, що ми використовуватимемо, та параметри, що ми хочемо передати:

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %% [markdown]
# Визначена вище функція складається з двох частин:
# 1. `search_url`: Це посилання кінцевої точки, до якої ми хочемо отримати доступ.
# 2. `query_params`: Параметри, що визначені кінцевою точкою (*end point*), і які можна використовувати для налаштування запиту.

# %% [markdown]
# API твіттера має багато різних кінцевих точок (*end point*). Нижче наданий їхній список, наявний на момент написання цієї статті, де за посиланням можна знайти специфікацію параметрів запиту для кожної кінцевої точки:
#
# | Категорія      | Кінцева точка                                                | Пояснення                                                    |
# |:--------------|:------------------------------------------------------------|:------------------------------------------------------------|
# | **Tweets**     | [**Tweet lookup**](https://developer.twitter.com/en/docs/twitter-api/tweets/lookup/introduction) | Шукати твіти за Ід.                                          |
# |                | [**Search Tweets**](https://developer.twitter.com/en/docs/twitter-api/tweets/search/introduction) | Запитати останні сім днів або повний архів твітів та отримати<br/>повну відповідь. Повна архівна кінцева точка пошуку<br/>наразі доступна лише у версії продукту *Academic Research*. |
# |                | [**Tweet counts**](https://developer.twitter.com/en/docs/twitter-api/tweets/counts/introduction) | Отримати кількість твітів за останні сім днів або з повного<br/>архіву, що відповідає запиту. Повна архівна кінцева точка підрахунку<br/>твітів наразі доступна лише у версії продукту *Academic Research*. |
# |                | [**Timelines**](https://developer.twitter.com/en/docs/twitter-api/tweets/timelines/introduction) | Отримати хронологію будь-яких твітів, складених з певного облікового<br/>запису Twitter, або згадок про певний обліковий запис Twitter. |
# |                | [**Filtered stream**](https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/introduction) | Відфільтрувати весь потік публічних твітів у реальному часі. |
# |                | [**Sampled stream**](https://developer.twitter.com/en/docs/twitter-api/tweets/sampled-stream/introduction) | Передавати порцію нових твітів по мірі їхньої публікації,<br/>біля ~ 1% усіх публічних твітів у режимі реального часу. |
# |                | **[Retweets](https://developer.twitter.com/en/docs/twitter-api/tweets/retweets/introduction)** | Отримати список облікових записів, які ретвітнули<br/>твіт або ретвіт, або скасували ретвіт твіту. |
# |                | [**Likes**](https://developer.twitter.com/en/docs/twitter-api/tweets/likes/introduction) | Отримати список користувачів, яким сподобався твіт, отримайте список<br/>твітів, що були вподобані або не вподобані користувачем. |
# |                | [**Hide replies**](https://developer.twitter.com/en/docs/twitter-api/tweets/hide-replies/introduction) | Приховати або показати відповідь на твіт.                    |
# | **Users**      | [**User lookup**](https://developer.twitter.com/en/docs/twitter-api/users/lookup/introduction) | Шукати користувачів за іменем або Ід.                        |
# |                | [**Follows**](https://developer.twitter.com/en/docs/twitter-api/users/follows/introduction) | Отримати послідовників облікового запису, отримати список, за ким підписався<br/>обліковий запис, або стежити за користувачем чи припинити слідкувати. |
# |                | [**Blocks**](https://developer.twitter.com/en/docs/twitter-api/users/blocks/introduction) | Отримати список користувачів, яких обліковий запис заблокував,<br/>або заблокувати та розблокувати користувача. |
# |                | **[Mutes](https://developer.twitter.com/en/docs/twitter-api/users/mutes/introduction)** | Вимкнути або увімкнути користувача                           |
# | **Spaces**     | **[Lookup Spaces](https://developer.twitter.com/en/docs/twitter-api/spaces/lookup)** | Пошук простору за допомогою Ід або імені автора              |
# |                | **[Search Spaces](https://developer.twitter.com/en/docs/twitter-api/spaces/search)** | Шукати простори за ключовим словом                           |
# | **Compliance** | **[Batch compliance](https://developer.twitter.com/en/docs/twitter-api/compliance/batch-compliance)** | Пакетне завантаження набору даних, щоб зрозуміти, що потрібно зробити,<br/>щоб ваші набори даних відображали поточний стан вмісту в Twitter. |

# %% [markdown]
# Параметри запиту можна розділити на три групи:
#
# | Ключове слово<br/>параметра запиту                           | Група параметрів                                             |
# | ------------------------------------------------------------ | ------------------------------------------------------------ |
# | 'query'<br/>'start_time'<br/>'end_time'<br/>'max_results'   | Параметри для контроля повернутого<br/>відгуку на запит          |
# | 'expansions'<br/>'tweet.fields'<br/>'user.fields'<br/>'place.fields' | Додаткові поля, що можна включити<br/>до відгуку на запит       |
# | 'next_token'                                                 | Ункальний ідентифікатор поля для доступу<br/>до наступної сторінки результатів |

# %% [markdown]
# ## Важливі деталі
#
# Тепер, коли ми знаємо, що робить функція `create_url`, декілька важливих деталей:
#
# ### Необхідні кінцеві точки:
#
# У разі повноархівної кінцевої точки пошуку параметр *query* є єдиним параметром, **необхідним** для подання запиту. Завжди переглядайте документацію щодо використовуваної кінцевої точки для належного формування параметрів запиту, щоб уникнути проблем.
#
# ### Параметр запиту:
#
# Параметр *query* - це місце, де ви розміщуєте ключові слова, що потрібно шукати.
#
# Запити можуть бути такими ж простими, як пошук твітів, що містять слово `'xbox'`, або такими складними, як-то `'(xbox europe) АБО (xbox usa)'`, що поверне твіти, що містять слова `'xbox AND europe або xbox AND usa'`.
#
# Крім того, *query* можна налаштувати з допомогою *операторів пошуку*. Існує так багато варіантів, які допомагають звузити результати пошуку. Повний список цих операторів можна знайти [тут](https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query).
#
# Приклад простого запиту з оператором: `'xbox lang:en'`.
#
# ### Мітки часу:
#
# Формат, що використовує Твіттер для параметрів (міток часу) *end_time* і *start_time*, відповідає стандарту ISO 8601/RFC 3339:
#
# * `YYYY-MM-DDTHH:mm:ss.fffZ`
#
# Тому обов’язково перетворіть потрібні дати в цей формат.
#
# ### Обсяг результатів:
#
# Кількість результатів пошуку, повернутих за запитом, наразі обмежена від 10 до 500 результатів.
#
# Тепер з'ясуємо як можна отримати більше 500 результатів? Ось тут гратиме *next_token* та розбивка на сторінки!
#
# Відповідь проста: якщо на ваш запит повернуто більше результатів, Twitter поверне унікальний *next_token*, що можна використати для наступного запиту і він поверне наступні нові результати.
#
# Якщо ви хочете отримати всі можливі твіти для вашого запиту, ви просто продовжуєте посилати запити, використовуючи щоразу новий (наступний) *next_token* доти, доки *next_token* не припинить існувати (`None`), сигналізуючи тим самим, що видобуті всі твіти.

# %% [markdown]
# ## Підключення до кінцевої точки
#
# Тепер, коли у нас є потрібна URL-адреса, заголовки та параметри, ми створимо функцію, що об’єднає все це разом і підключиться до кінцевої точки.
#
# Нижче наведена функція надішле запит “GET”, і якщо все вірно (код відповіді 200), вона поверне відповідь у форматі “JSON”.
#
# **Примітка:** за замовчуванням для *next_token* встановлено значення `None`, оскільки нас цікавить результат лише за наявності *next_token.

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %% [markdown]
# ## Об’єднаємо все разом
#
# Тепер, коли у нас є всі необхідні функції, давайте спробуємо зібрати їх усі разом, щоб створити наш перший запит!
# У наступній комірці ми налаштуємо наші вхідні дані:
#
# * *bearer_token* та заголовки з API.
# * Ми будемо шукати твіти англійською мовою, що містять слово “xbox”.
# * Ми будемо шукати твіти в межах останніх 7 днів (стільки дозволяє мій бекоштовний тарифний план). Також обв'язково зазначте мікросекунди в шаблоні часу - інакше Твіттер не пропустить.
# * Ми хочемо повернути максимум 15 твітів.

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = 'geocode:50.449949,30.523217,30km (воздух OR воздуха)'

def twt_datetime_str(dt):
    return dt.strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3] + 'Z'

end_time = datetime.datetime.now() - datetime.timedelta(hours=4)
start_time = end_time - datetime.timedelta(days=6)
end_time = twt_datetime_str(end_time)
start_time = twt_datetime_str(start_time)

max_results = 15

# %%
url = create_url(keyword, start_time,end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "author_id": "43649014",
#             "conversation_id": "1437951008320196618",
#             "created_at": "2021-09-16T13:52:44.000Z",
#             "id": "1438501106741612547",
#             "in_reply_to_user_id": "71206457",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438105122446487557",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "@Orangecroc @tomwarren @Xbox This works on Xbox controllers?? Because that seems really cool if the thing protruding out doesn't get in the way (I don't think it would, just a thought lmao)"
#         },
#         {
#             "author_id": "3045537172",
#             "conversation_id": "1438242221631938576",
#             "created_at": "2021-09-16T13:52:43.000Z",
#             "id": "1438501102287261701",
#             "in_reply_to_user_id": "949470149165318144",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438455898998034435",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@RiascosJacob @AaronSobush @stlcty03 Yeah but xbots Dont like good stories they just like mindless open world games like sea of thieves, roblox and minecraft. Because i know people who only have an xbox that wish spiderman 2 was coming to xbox. Or even wolverine. They needa stop the cap"
#         },
#         {
#             "author_id": "73011288",
#             "conversation_id": "1438501080845877253",
#             "created_at": "2021-09-16T13:52:38.000Z",
#             "id": "1438501080845877253",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438489497319129089",
#                     "type": "quoted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "oh wow, can't believe Xbox Game Pass has over 100 great games on console and PC with day-in-date Xbox Game Studios releases like Forza Horizon 5 &amp; Halo Infinite coming this year, I'm getting hyped just thinking about it \ud83e\udd72 \ud83d\ude0d https://t.co/hdAbzhd6St"
#         },
#         {
#             "author_id": "16514469",
#             "conversation_id": "1438501079302373379",
#             "created_at": "2021-09-16T13:52:38.000Z",
#             "id": "1438501079302373379",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Exophase",
#             "text": "mrxbob played Psychonauts 2 (Xbox) in the last 24 hours https://t.co/bBWQUQPRGE #exophase"
#         },
#         {
#             "author_id": "106813857",
#             "conversation_id": "1438501072096485376",
#             "created_at": "2021-09-16T13:52:36.000Z",
#             "id": "1438501072096485376",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 66
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438491534912069636",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "TweetDeck",
#             "text": "RT @gematsucom: BloodRayne: ReVamped and BloodRayne 2: ReVamped announced for PS4, Xbox One, and\u00a0Switch https://t.co/EJ7MGSEpi5 https://t.c\u2026"
#         },
#         {
#             "author_id": "1849620716",
#             "conversation_id": "1438501071899484163",
#             "created_at": "2021-09-16T13:52:36.000Z",
#             "id": "1438501071899484163",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438380805760241666",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @PercyXIII: Got #Vanguard pre-ordered for the Xbox, sadly I have to work overtime this Friday night but Saturday night I\u2019m telling y\u2019all\u2026"
#         },
#         {
#             "author_id": "90191924",
#             "conversation_id": "1438501057605210116",
#             "created_at": "2021-09-16T13:52:32.000Z",
#             "id": "1438501057605210116",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 2,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "reading that Lost Judgement is a step *down* for the depiction of women in RGG Studio games is making my head spin. how much worse could it possibly get? https://t.co/ngZZK9nJl0"
#         },
#         {
#             "author_id": "90904813",
#             "conversation_id": "1438501056799907843",
#             "created_at": "2021-09-16T13:52:32.000Z",
#             "id": "1438501056799907843",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Go Read The Fantasy Action Comedy Here! https://t.co/jUkJqyNu8F\n\n#scifi #anime #manga #artistsontwitter #japan #fantasy #cyberpunk #ninja #ps5 #artist #drawing #sketches #sketching #XboxSeriesS #zombies #artwork #drawings #fantasyart #Xbox #XboxSeriesX #PlayStation #books"
#         },
#         {
#             "author_id": "2835625406",
#             "conversation_id": "1438501039456481283",
#             "created_at": "2021-09-16T13:52:28.000Z",
#             "id": "1438501039456481283",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 4,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438494580853272576",
#                     "type": "quoted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "$PSRU huge demand on video games. $860 Million in REVS for this 1 basketball game alone. PSRU game will be sold for the same PS5/XBOX platforms. https://t.co/pgOE0ADPnH https://t.co/tkuYWZ3C5y"
#         },
#         {
#             "author_id": "1269699176700526592",
#             "conversation_id": "1438190048206147585",
#             "created_at": "2021-09-16T13:52:26.000Z",
#             "id": "1438501029511774215",
#             "in_reply_to_user_id": "1281048287840264192",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 1
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438498891058589701",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Jacep_yt @Turn10Studios @ForzaMotorsport @ForzaHorizon @Xbox @XboxBR @FallenWolf_146 @PTGforza @jgoodmanartist @robi4tv @XboxMexico @officialDannyT @TrejosTacos Cheers buddy!!! \ud83e\udd19"
#         },
#         {
#             "author_id": "3030193577",
#             "conversation_id": "1438501027100069896",
#             "created_at": "2021-09-16T13:52:25.000Z",
#             "id": "1438501027100069896",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 26
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438382685307633665",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @majornelson: I Am Fish is now available for Windows 10, Xbox One, and Xbox Series X|S. Save 10% - limited time offer. I Am Fish is also\u2026"
#         },
#         {
#             "author_id": "110519649",
#             "conversation_id": "1438496881315876866",
#             "created_at": "2021-09-16T13:52:24.000Z",
#             "id": "1438501020502355974",
#             "in_reply_to_user_id": "328078549",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438500215309447169",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@Melo047 @theRealJayDub2 @nxtgen8k Let Sony help you grow that Xbox stink won't let you grow like grid , let us ponies help you sign the Kratos contract"
#         },
#         {
#             "author_id": "1139189483235172352",
#             "conversation_id": "1438501018929549322",
#             "created_at": "2021-09-16T13:52:23.000Z",
#             "id": "1438501018929549322",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "WordPress.com",
#             "text": "Ziggurat Interactive ha annunciato BloodRayne: ReVamped e BloodRayne 2: ReVamped per PS4, Xbox One e Switch in uscita questo Autunno.\n#bloodraynerevamped #bloodrayne2revamped #ps4 #xboxone #switch #zigguratinteractive https://t.co/ueiUHlcSVZ"
#         },
#         {
#             "author_id": "56566855",
#             "conversation_id": "1438501000944316422",
#             "created_at": "2021-09-16T13:52:19.000Z",
#             "id": "1438501000944316422",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 18
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438461271893028871",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @XboxGamePassUK: Available Today on Xbox Game Pass \ud83d\udc9a\n\n\ud83d\udc1f I am Fish - \ud83c\udfae/\ud83d\udda5/\u2601\n\ud83d\udc26 SkateBIRD - \ud83c\udfae/\ud83d\udda5/\u2601\n\ud83d\udc40 Superliminal - \ud83c\udfae/\ud83d\udda5/\u2601\n\nwe forgot the emph\u2026"
#         },
#         {
#             "author_id": "70466918",
#             "conversation_id": "1438500998981451782",
#             "created_at": "2021-09-16T13:52:18.000Z",
#             "id": "1438500998981451782",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 25
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1438496663312781315",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "RT @QuarantinedCoof: It's almost been a year (November) since the PS5 launched and it's still out of stock everywhere due to limited supply\u2026"
#         }
#     ],
#     "includes": {
#         "users": [
#             {
#                 "created_at": "2009-05-31T05:40:15.000Z",
#                 "description": "Hope I don't say or do anything stupid (He/Him)",
#                 "id": "43649014",
#                 "name": "Pop Star Peej",
#                 "public_metrics": {
#                     "followers_count": 157,
#                     "following_count": 161,
#                     "listed_count": 2,
#                     "tweet_count": 24049
#                 },
#                 "username": "LiterallyNoodle",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-09-03T08:33:06.000Z",
#                 "description": "Variety Gaming creator focused on Story & Vehicle games. \n(he/him) \nhttps://t.co/WXKerCW2qw\nLinks\nhttps://t.co/YmrnWNEuHk\nEmail:Orangecroc@hotmail.co.uk",
#                 "id": "71206457",
#                 "name": "orangecroc \ud83c\udf4a\ud83d\udc0aWill be @EGX",
#                 "public_metrics": {
#                     "followers_count": 347,
#                     "following_count": 347,
#                     "listed_count": 3,
#                     "tweet_count": 4872
#                 },
#                 "username": "Orangecroc",
#                 "verified": false
#             },
#             {
#                 "created_at": "2015-02-20T01:57:18.000Z",
#                 "description": "#ps5 (Music recording major). Currently working on my first album.  Gaming YouTube Channel: RouVerick's World\n \"If you're a bot... GET OUT OF MY GAME\"",
#                 "id": "3045537172",
#                 "name": "RouVericks World",
#                 "public_metrics": {
#                     "followers_count": 146,
#                     "following_count": 243,
#                     "listed_count": 2,
#                     "tweet_count": 1702
#                 },
#                 "username": "ABeastmode23",
#                 "verified": false
#             },
#             {
#                 "created_at": "2018-01-06T02:38:18.000Z",
#                 "description": "a guy who is everywhere",
#                 "id": "949470149165318144",
#                 "name": "Young special",
#                 "public_metrics": {
#                     "followers_count": 56,
#                     "following_count": 35,
#                     "listed_count": 0,
#                     "tweet_count": 13677
#                 },
#                 "username": "RiascosJacob",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-09-10T01:44:33.000Z",
#                 "description": "Antip\u00e1tico pero sabio | \nEditor at @An0therNoob | \nFrontend in Hyrule | \nGamer in Chief at @NFTLatinoART | \n@Xbox RLZ! | \nS\u00edgueme: \u27a1\ufe0f\u27a1\ufe0f https://t.co/cxzihN76kT",
#                 "id": "73011288",
#                 "name": "God Link",
#                 "public_metrics": {
#                     "followers_count": 1291,
#                     "following_count": 1299,
#                     "listed_count": 29,
#                     "tweet_count": 57228
#                 },
#                 "username": "LinkStrifer",
#                 "verified": false
#             },
#             {
#                 "created_at": "2008-09-29T17:19:05.000Z",
#                 "description": "Just enjoy games and stop being silly.",
#                 "id": "16514469",
#                 "name": "Neil Smith",
#                 "public_metrics": {
#                     "followers_count": 1363,
#                     "following_count": 1249,
#                     "listed_count": 45,
#                     "tweet_count": 81014
#                 },
#                 "username": "MrXBob",
#                 "verified": false
#             },
#             {
#                 "created_at": "2010-01-20T19:41:28.000Z",
#                 "description": "Geek, Retrogameur , D\u00e9pressif et M\u00e9talleux !! Beau m\u00e9lange, non !\n(Mais toujours avec une pointe d'ironie !)\r\nJe ne suis pas Alain Huygues Lacour.",
#                 "id": "106813857",
#                 "name": "Ahl {Daisy \ud83d\udc94}",
#                 "public_metrics": {
#                     "followers_count": 2877,
#                     "following_count": 378,
#                     "listed_count": 155,
#                     "tweet_count": 816660
#                 },
#                 "username": "ahl9",
#                 "verified": false
#             },
#             {
#                 "created_at": "2013-09-09T22:30:01.000Z",
#                 "description": "streamer For @TheWaveRises (\u2764\ufe0f\ud83d\udc8d @gt_nala) https://t.co/Xpev1dZV9W",
#                 "id": "1849620716",
#                 "name": "Simba \u6012\u308a",
#                 "public_metrics": {
#                     "followers_count": 981,
#                     "following_count": 817,
#                     "listed_count": 14,
#                     "tweet_count": 29614
#                 },
#                 "username": "SenseiSimba",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-11-15T16:19:31.000Z",
#                 "description": "vibing at the end of everything ~ writer ~ streams @RadicalHeartz ~ autistic ~ 26, they/them ~ polyam/pan ~ priv: @EbyHours ~ FFXIV: @WoodabaXiv",
#                 "id": "90191924",
#                 "name": "papyrus undertale's skateboarding maid",
#                 "public_metrics": {
#                     "followers_count": 233,
#                     "following_count": 134,
#                     "listed_count": 3,
#                     "tweet_count": 14848
#                 },
#                 "username": "woodaba2",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-11-18T16:33:22.000Z",
#                 "description": "Author / Artist / Musician. GO! https://t.co/nqL58hzulL\n\u8457\u8005/\u30a2\u30fc\u30c6\u30a3\u30b9\u30c8/\u30df\u30e5\u30fc\u30b8\u30b7\u30e3\u30f3",
#                 "id": "90904813",
#                 "name": "Sid",
#                 "public_metrics": {
#                     "followers_count": 148,
#                     "following_count": 2200,
#                     "listed_count": 35,
#                     "tweet_count": 26313
#                 },
#                 "username": "PWpublishing1",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-09-29T20:46:30.000Z",
#                 "description": "OTC Specialist. Logic, Extensive Research and Common Sense is what we bring to the table at Due Diligence Virtuoso. \ud83d\udd25\ud83d\udd25\ud83d\udd25",
#                 "id": "2835625406",
#                 "name": "Due Diligence Virtuoso",
#                 "public_metrics": {
#                     "followers_count": 6100,
#                     "following_count": 468,
#                     "listed_count": 51,
#                     "tweet_count": 6100
#                 },
#                 "username": "stock_hacker",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-06-07T18:34:22.000Z",
#                 "description": "Dad. Husband. Art Director. Graphic Designer. Livery Design. Car & Forza franchise enthusiast. Proud member of PTG.",
#                 "id": "1269699176700526592",
#                 "name": "PTG FLUEX",
#                 "public_metrics": {
#                     "followers_count": 617,
#                     "following_count": 638,
#                     "listed_count": 4,
#                     "tweet_count": 3097
#                 },
#                 "username": "Fluex_Artworks",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-07-09T02:12:15.000Z",
#                 "description": "hi I play Forza Horizon 4 I make picture my Xbox name Jaceyt \ud83d\ude0e and follow my friend @racing_og",
#                 "id": "1281048287840264192",
#                 "name": "Jace_yt",
#                 "public_metrics": {
#                     "followers_count": 99,
#                     "following_count": 152,
#                     "listed_count": 0,
#                     "tweet_count": 5229
#                 },
#                 "username": "Jacep_yt",
#                 "verified": false
#             },
#             {
#                 "created_at": "2015-02-11T12:24:50.000Z",
#                 "description": "Product Manager @Unity Technologies. Transmedia, real-time graphics, for films and games, mostly madewithunity. Views are my own.",
#                 "id": "3030193577",
#                 "name": "Mathieu",
#                 "public_metrics": {
#                     "followers_count": 1295,
#                     "following_count": 482,
#                     "listed_count": 57,
#                     "tweet_count": 3493
#                 },
#                 "username": "the_f_key",
#                 "verified": false
#             },
#             {
#                 "created_at": "2010-02-01T20:59:33.000Z",
#                 "description": "the views and thoughts from this profile is mines and mines alone if you do not like them I do not care I will say what I feel now have a gday\n\npsn:DietyLink999",
#                 "id": "110519649",
#                 "name": "DarkLink - Vileblood of Tsushima",
#                 "public_metrics": {
#                     "followers_count": 583,
#                     "following_count": 1064,
#                     "listed_count": 1,
#                     "tweet_count": 26691
#                 },
#                 "username": "DarkLink999",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-07-02T17:56:25.000Z",
#                 "description": "#YourWifeyFavGamer #JoeBuddenOfVideoGames #StatusGaming #LeafCaivar #AlumniStatus  #WatchThaComeUp #GraduateUrBrand https://t.co/bsXraj3MrQ",
#                 "id": "328078549",
#                 "name": "double0melo",
#                 "public_metrics": {
#                     "followers_count": 322,
#                     "following_count": 406,
#                     "listed_count": 4,
#                     "tweet_count": 6250
#                 },
#                 "username": "Melo047",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-06-13T15:15:12.000Z",
#                 "description": "La CrazyGameCommunity, o abbreviata CGC, nasce nel 2014 da un\u2019idea di Davide (ThePlayer96) e Alessandro (WitherBoy).",
#                 "id": "1139189483235172352",
#                 "name": "CrazyGameCommunity",
#                 "public_metrics": {
#                     "followers_count": 8,
#                     "following_count": 0,
#                     "listed_count": 1,
#                     "tweet_count": 2758
#                 },
#                 "username": "CGCOfficial_",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-07-14T01:44:51.000Z",
#                 "description": "\u2605 Final Fantasy XIV - SCH \u2606 Steam: Maora_D63 \u2664 Xbox: Maora D63 \u2667 Switch: 4140-6294-3053 \u2662 Gamer\ud83c\udfae \u2661 Fan of Anime... Will of D ...Warrior of Light",
#                 "id": "56566855",
#                 "name": "\u2b50Maora\u2b50",
#                 "public_metrics": {
#                     "followers_count": 638,
#                     "following_count": 454,
#                     "listed_count": 45,
#                     "tweet_count": 240670
#                 },
#                 "username": "AggroQueenFay",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-08-31T18:44:43.000Z",
#                 "description": "Gamer, Far Leftist, #NotYourShield egalitarian, director, synesthesia, CFIDS, Catholic, abuse survivor. #MMIW Recovering workaholic",
#                 "id": "70466918",
#                 "name": "Capitalist Environmentalist",
#                 "public_metrics": {
#                     "followers_count": 1706,
#                     "following_count": 1975,
#                     "listed_count": 62,
#                     "tweet_count": 108366
#                 },
#                 "username": "silverwolfcc",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1438501106741612547",
#         "next_token": "b26v89c19zqg8o3fpdp9m1d4l001a3gqwkb47ti2dpsot",
#         "oldest_id": "1438500998981451782",
#         "result_count": 15
#     }
# }

# %% [markdown]
# ### Використання отриманих даних
#
# Отримані дані предствлені списком словників, кожен з яких представляє дані окремого твіту. Нижче наведений приклад отримання часу створення першого твіту:

# %%
json_response['data'][0]['created_at']
# Out:
# '2021-09-16T13:52:44.000Z'

# %% [markdown]
# ### Мета дані запиту
#
# Мета дані запиту представлені словником атрибутів запиту. Зазвичай нас буде цікавити лише про два параметри в цьому словнику, а саме: *next_token* та *result_count*.

# %%
json_response['meta']['result_count']
# Out:
# 15

# %%
json_response['meta']['next_token']
# Out:
# 'b26v89c19zqg8o3fpdp9m1d4l001a3gqwkb47ti2dpsot'

# %% [markdown]
# ## Збереження результатів
#
# У нас є два варіанти збереження результатів: або зберегаємо результати у тому ж форматі JSON, що ми отримали, або у форматі CSV.
#
# Зберегти результати в JSON можна легко з допомогою двох рядків коду:

# %%
with open('data_test.json', 'w') as f:
    json.dump(json_response, f)

# %% [markdown]
# ### CSV
#
# #### Простий підхід
#
# Простий підхід просто сконструювати з допомогою стандартних бібліотек. Але він не розрахований на вкладені структури словників. Для цього підходу використовуємо пакет *Pandas*:

# %%
df = pd.DataFrame(json_response['data'])
df.to_csv('data_test_simple.csv')

# %% [markdown]
# #### Власний підхід
#
# Спочатку створимо файл CSV з потрібними заголовками стовпців. Зробимо це окремо від нашої фактичної функції, щоб згодом це не заважало циклічному перегляду запитів.

# %%
# Create file
csvFile = open("data_test_custom.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

# %% [markdown]
# Потім створимо нашу основну функцію `append_to_csv`, у яку вхідними аргументами подамо відповідь на запит `json_response` та ім’я файлу `fileName`, а функція додасть усі зібрані нами дані до файлу CSV.

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 4. Tweet ID
        tweet_id = tweet['id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %% [markdown]
# Тепер, коли ми запустимо нашу функцію `append_to_csv()`, ми маємо отримати файл, що містить 15 твітів (або менше, залежно від результату запиту)

# %%
append_to_csv(json_response, "data_test_custom.csv")
# Out:
# # of Tweets added from this response:  15

# %% [markdown]
# Отже, ми можемо встановити обмеження на кількість твітів, що ми збираємо за певний період часу, так що, якщо ми досягнемо певного (встановленого нами) обмеження за цей період, ми перейдемо до наступного.
#
# Код нижче - це приклад, що точно зробить це! Цей блок коду складається з двох циклів:
#
# 1. Цикл `for`, що перебирає ці періоди часу (залежно від того, як це налаштовано)
# 2. Цикл `While`, що контролює максимальну кількість твітів, що ми хочемо зібрати за певний період часу.
#
# Зверніть увагу, що між викликами додається `time.sleep()`, щоб переконатися, що ви не просто спасимите API через запити.

# %%
#Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = 'geocode:50.449949,30.523217,30km (воздух OR воздуха)'

end_time = datetime.datetime.now() - datetime.timedelta(hours=4)
time_list = [end_time - datetime.timedelta(days=x) for x in [6,4,2,0]]
start_list = [twt_datetime_str(time_list[i]) for i in range(3)]
end_list = [twt_datetime_str(time_list[i]) for i in range(1,4)]

max_results = 50

#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
data_complete_file = "data_complete.csv"
csvFile = open(data_complete_file, "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 100 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        print("-------------------")
        print("Token: ", next_token)
        url = create_url(keyword, start_list[i],end_list[i], max_results)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, data_complete_file)
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                print("-------------------")
                print("Start Date: ", start_list[i])
                append_to_csv(json_response, data_complete_file)
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(5)
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdp96l51wwmjdhl706s56o6vqzzwd
# Start Date:  2021-09-10T13:53:52.545Z
# # of Tweets added from this response:  50
# Total # of Tweets added:  50
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdp96l51wwmjdhl706s56o6vqzzwd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdp96l51wvrs7d6d983xxha5rctq5
# Start Date:  2021-09-10T13:53:52.545Z
# # of Tweets added from this response:  50
# Total # of Tweets added:  100
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdp9702qqnztl76m8d8zy7zp5xunx
# Start Date:  2021-09-12T13:53:52.545Z
# # of Tweets added from this response:  50
# Total # of Tweets added:  150
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdp9702qqnztl76m8d8zy7zp5xunx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdp9702qp6fugip3xknp46awc724d
# Start Date:  2021-09-12T13:53:52.545Z
# # of Tweets added from this response:  49
# Total # of Tweets added:  199
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdp9702qp6fugip3xknp46awc724d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdp9702qp55zyr7z91ophxi23hsot
# Start Date:  2021-09-12T13:53:52.545Z
# # of Tweets added from this response:  50
# Total # of Tweets added:  249
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdp9m1d4mgwsbykrtsrqj8ulk1unx
# Start Date:  2021-09-14T13:53:52.545Z
# # of Tweets added from this response:  50
# Total # of Tweets added:  299
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fpdp9m1d4mgwsbykrtsrqj8ulk1unx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fpdp9m1d4kzkm1hj2s0s2mcmym0br1
# Start Date:  2021-09-14T13:53:52.545Z
# # of Tweets added from this response:  50
# Total # of Tweets added:  349
# -------------------
# Total number of results:  349

# %% [markdown]
# Перевірте ваш робочий фолдер — там з’явились 4 згенерованих файли:
#
# - `data_test.json`
# - `data_test_simple.csv`
# - `data_test_custom.csv`
# - `data_complete.csv`
#
# Якщо так, то вітаю вас — все працює!
